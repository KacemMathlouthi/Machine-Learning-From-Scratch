# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from LinearRegression import LinearRegression

# %%
X, y = datasets.make_regression(n_samples = 500, n_features=1, noise = 25, random_state=4)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1234)

# %%
fig = plt.figure(figsize=(8,6))
plt.scatter(X[:,0], y, color = "b", marker = "o", s = 30)
plt.show()

# %%
model = LinearRegression()
model.fit(X_train, y_train)

# %%
predictions = model.predict(X_test)

# %%
def mse(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# %%
error = mse(y_test, predictions)
print("The MSE Error is : " + str(error))
# Out:
# The MSE Error is : 660.319099227036

# %%
for learning_rate in [0.1, 0.01, 0.001, 0.0001]:
    for n_iters in [100, 1000, 5000, 10000]:
        test_model = LinearRegression(learning_rate=learning_rate, n_iters=n_iters)
        test_model.fit(X_train, y_train)
        predictions = test_model.predict(X_test)
        error = mse(y_test, predictions)
        print("The MSE Error for n_iters = " + str(n_iters) + " and learning rate = " + str(learning_rate) + " is " + str(error))
# Out:
# The MSE Error for n_iters = 100 and learning rate = 0.1 is 564.4896249562462
# The MSE Error for n_iters = 1000 and learning rate = 0.1 is 564.4896247842622
# The MSE Error for n_iters = 5000 and learning rate = 0.1 is 564.4896247842622
# The MSE Error for n_iters = 10000 and learning rate = 0.1 is 564.4896247842622
# The MSE Error for n_iters = 100 and learning rate = 0.01 is 657.546922527976
# The MSE Error for n_iters = 1000 and learning rate = 0.01 is 564.4896256756289
# The MSE Error for n_iters = 5000 and learning rate = 0.01 is 564.4896247842629
# The MSE Error for n_iters = 10000 and learning rate = 0.01 is 564.4896247842629
# The MSE Error for n_iters = 100 and learning rate = 0.001 is 3048.122627109368
# The MSE Error for n_iters = 1000 and learning rate = 0.001 is 660.319099227036
# The MSE Error for n_iters = 5000 and learning rate = 0.001 is 564.4983707414253
# The MSE Error for n_iters = 10000 and learning rate = 0.001 is 564.4896258152196
# ...

# %%
y_pred_line = model.predict(X)
cmap = plt.get_cmap('viridis')
fig = plt.figure(figsize=(8,6))
m1 = plt.scatter(X_train, y_train, color=cmap(0.9), s=10)
m2 = plt.scatter(X_test, y_test, color=cmap(0.5), s=10)
plt.plot(X, y_pred_line, color='black', linewidth=2, label='Prediction')
plt.show()
